# %%
def model_SVM(X,y):
    from sklearn.svm import SVC
    from sklearn.utils import shuffle
    from sklearn.model_selection import cross_val_score

    X_shuff,y_shuff = shuffle(X,y)
    model = SVC(kernel='rbf')
    cross = cross_val_score(model, X_shuff, y_shuff, cv=5, n_jobs=-1)

    model = SVC(kernel='rbf')
    model.fit(X_shuff, y_shuff)
    ans = model.predict(X_shuff)
    acc = sum(ans == y_shuff) / len(y_shuff)
    return model, acc, cross

def model_LR(X,y):
    from sklearn.linear_model import LogisticRegression
    from sklearn.utils import shuffle
    from sklearn.model_selection import cross_val_score
    
    X_shuff,y_shuff = shuffle(X,y)
    model = LogisticRegression()
    cross = cross_val_score(model, X_shuff, y_shuff, cv=5, n_jobs=-1)

    model = LogisticRegression()
    model.fit(X_shuff, y_shuff)
    ans = model.predict(X_shuff)
    acc = sum(ans == y_shuff) / len(y_shuff)
    return model, acc, cross

def model_NB(X,y):
    from sklearn.naive_bayes import GaussianNB
    from sklearn.utils import shuffle
    from sklearn.model_selection import cross_val_score

    X_shuff,y_shuff = shuffle(X,y)
    model = GaussianNB()
    cross = cross_val_score(model, X_shuff, y_shuff, cv=5, n_jobs=-1)

    model = GaussianNB()
    model.fit(X_shuff, y_shuff)
    ans = model.predict(X_shuff)
    acc = sum(ans == y_shuff) / len(y_shuff)
    return model, acc, cross

def model_KNN(X,y):
    from sklearn.neighbors import KNeighborsClassifier
    from sklearn.utils import shuffle
    from sklearn.model_selection import cross_val_score

    X_shuff,y_shuff = shuffle(X,y)
    model = KNeighborsClassifier()
    cross = cross_val_score(model, X_shuff, y_shuff, cv=5, n_jobs=-1)

    model = KNeighborsClassifier(n_neighbors = 2)
    model.fit(X_shuff, y_shuff)
    ans = model.predict(X_shuff)
    acc = sum(ans == y_shuff) / len(y_shuff)
    return model, acc, cross

def model_RF(X,y):
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.utils import shuffle
    from sklearn.model_selection import cross_val_score

    X_shuff,y_shuff = shuffle(X,y)
    model = RandomForestClassifier()
    cross = cross_val_score(model, X_shuff, y_shuff, cv=5, n_jobs=-1)

    model = RandomForestClassifier()
    model.fit(X_shuff, y_shuff)
    ans = model.predict(X_shuff)
    acc = sum(ans == y_shuff) / len(y_shuff)
    return model, acc, cross

# %%
def test_pipe(X_test,y_test,model):
    from sklearn.metrics import accuracy_score  
    from sklearn.metrics import classification_report
    from sklearn.metrics import confusion_matrix
    import seaborn as sns
    import matplotlib.pyplot as plt
    model = model
    y_pred = model.predict(X_test)
    target_names = ['without Stress', 'with Stress']
    acc = accuracy_score(y_test,y_pred)
    # crp = classification_report(y_test,y_pred, target_names=target_names)
    print("Test Acc :",acc)
    # print("classification_report : \n",crp)
    # print(sns.heatmap(confusion_matrix(y_test,y_pred),annot=True))
    # plt.show()

# %%
def train_pipe(X_train, X_test, y_train, y_test):
    X,y = X_train.copy(),y_train.copy()
    model, acc, cross = model_SVM(X,y)
    print(f'{model}\n Train Acc : {acc:.4f} Score :{cross.mean():.4f}',end=' ')
    test_pipe(X_test, y_test ,model)
    X,y = X_train.copy(),y_train.copy()
    model, acc, cross = model_LR(X,y) 
    print(f'{model}\n Train Acc : {acc:.4f} Score :{cross.mean():.4f}',end=' ')
    test_pipe(X_test, y_test ,model)
    X,y = X_train.copy(),y_train.copy()
    model, acc, cross = model_NB(X,y)
    print(f'{model}\n Train Acc : {acc:.4f} Score :{cross.mean():.4f}',end=' ')
    test_pipe(X_test, y_test ,model)
    X,y = X_train.copy(),y_train.copy()
    model, acc, cross = model_KNN(X,y)
    print(f'{model}\n Train Acc : {acc:.4f} Score :{cross.mean():.4f}',end=' ')
    test_pipe(X_test, y_test ,model)
    X,y = X_train.copy(),y_train.copy()
    model, acc, cross = model_RF(X,y)
    print(f'{model}\n Train Acc : {acc:.4f} Score :{cross.mean():.4f}',end=' ')
    test_pipe(X_test, y_test ,model)

# %%
import pandas as pd
import numpy as np

# %%
df_train = pd.read_csv('./data/train_set.csv')
df_train.shape
# Out:
# (336, 145)

# %%
df_train.head()
# Out:
#    Unnamed: 0  mean_Delta  mean_Theta  mean_Alpha   mean_Beta  mean_Gamma  \
# 0           0 -110.329965 -121.299482 -123.725032 -131.335399 -134.971232
# 1           1 -110.383640 -121.158052 -123.636121 -130.643007 -134.449370
# 2           2 -111.593383 -120.712248 -124.276396 -130.440765 -134.357490
# 3           3 -111.292704 -122.189083 -123.512155 -128.614875 -135.116331
# 4           4 -113.361314 -119.989890 -123.255042 -130.600926 -135.144714
#
#     mean_Slow  mean_Low_beta  mean_Relative_gamma   Fp1_Delta  ...  \
# 0 -123.031043    -128.526178             0.911535 -106.209371  ...
# 1 -123.097757    -128.670923             0.915570 -107.994728  ...
# 2 -123.286220    -130.602665             0.917598 -110.782820  ...
# 3 -123.276588    -127.691734             0.912374 -108.605531  ...
# 4 -122.298936    -129.782153             0.904948 -109.577307  ...
#
#    O2_Low_beta  O2_Relative_gamma  alpha_frontal  alpha_temporal  \
# 0  -127.567021           0.902035      -0.002908       -0.000649
# 1  -130.006559           0.915688      -0.005629       -0.008944
# 2  -131.785838           0.918551      -0.003908       -0.004460
# 3  -129.835990           0.924993      -0.005010        0.010191
# 4  -131.338841           0.901524       0.001069       -0.002919
#
#    alpha_asymmetry  beta_frontal  beta_temporal  beat_asymmetry  \
# 0        -0.003557     -0.002668       0.010859        0.008191
# 1        -0.014573     -0.001315       0.003450        0.002135
# 2        -0.008369      0.000354       0.002001        0.002355
# 3         0.005181     -0.005576       0.003535       -0.002042
# 4        -0.001850     -0.007245       0.008795        0.001550
#
#    participant_id  label
# 0               1      1
# 1               1      1
# 2               1      1
# 3               1      1
# 4               1      1
#
# [5 rows x 145 columns]

# %%
np.unique(df_train['label'], return_counts=True)
# Out:
# (array([0, 1], dtype=int64), array([192, 144], dtype=int64))

# %%
label_1 = df_train.loc[df_train['label'] == 1]
label_1.shape

label_0 = df_train.loc[df_train['label'] == 0].sample(n=label_1.shape[0], random_state=999)
label_0.shape

df_train = pd.concat([label_1, label_0])
df_train['label'].value_counts()
# Out:
# 1    144
# 0    144
# Name: label, dtype: int64

# %%
df_train = df_train[['mean_Alpha', 'mean_Beta', 'mean_Relative_gamma', 'alpha_frontal', 'alpha_temporal', 'alpha_asymmetry', 'beta_frontal', 'beta_temporal', 'beat_asymmetry', 'participant_id', 'label']]
df_train.head()
# Out:
#    mean_Alpha   mean_Beta  mean_Relative_gamma  alpha_frontal  alpha_temporal  \
# 0 -123.725032 -131.335399             0.911535      -0.002908       -0.000649
# 1 -123.636121 -130.643007             0.915570      -0.005629       -0.008944
# 2 -124.276396 -130.440765             0.917598      -0.003908       -0.004460
# 3 -123.512155 -128.614875             0.912374      -0.005010        0.010191
# 4 -123.255042 -130.600926             0.904948       0.001069       -0.002919
#
#    alpha_asymmetry  beta_frontal  beta_temporal  beat_asymmetry  \
# 0        -0.003557     -0.002668       0.010859        0.008191
# 1        -0.014573     -0.001315       0.003450        0.002135
# 2        -0.008369      0.000354       0.002001        0.002355
# 3         0.005181     -0.005576       0.003535       -0.002042
# 4        -0.001850     -0.007245       0.008795        0.001550
#
#    participant_id  label
# 0               1      1
# 1               1      1
# 2               1      1
# 3               1      1
# 4               1      1

# %%
df_train.columns = ['alpha', 'beta', 'relative_gamma', 'alpha_frontal', 'alpha_temporal', 'alpha_asymmetry', 'beta_frontal', 'beta_temporal', 'beta_asymmetry', 'participant_id', 'label']

# %%
df_train.head()
# Out:
#         alpha        beta  relative_gamma  alpha_frontal  alpha_temporal  \
# 0 -123.725032 -131.335399        0.911535      -0.002908       -0.000649
# 1 -123.636121 -130.643007        0.915570      -0.005629       -0.008944
# 2 -124.276396 -130.440765        0.917598      -0.003908       -0.004460
# 3 -123.512155 -128.614875        0.912374      -0.005010        0.010191
# 4 -123.255042 -130.600926        0.904948       0.001069       -0.002919
#
#    alpha_asymmetry  beta_frontal  beta_temporal  beta_asymmetry  \
# 0        -0.003557     -0.002668       0.010859        0.008191
# 1        -0.014573     -0.001315       0.003450        0.002135
# 2        -0.008369      0.000354       0.002001        0.002355
# 3         0.005181     -0.005576       0.003535       -0.002042
# 4        -0.001850     -0.007245       0.008795        0.001550
#
#    participant_id  label
# 0               1      1
# 1               1      1
# 2               1      1
# 3               1      1
# 4               1      1

# %%
df_test = pd.read_csv('./data/test_set.csv')
df_test = df_test[['mean_Alpha', 'mean_Beta', 'mean_Relative_gamma', 'alpha_frontal', 'alpha_temporal', 'alpha_asymmetry', 'beta_frontal', 'beta_temporal', 'beat_asymmetry', 'participant_id', 'label']]
df_test.columns = ['alpha', 'beta', 'relative_gamma', 'alpha_frontal', 'alpha_temporal', 'alpha_asymmetry', 'beta_frontal', 'beta_temporal', 'beta_asymmetry', 'participant_id', 'label']

# %% [markdown]
# #### Select only Asymmetry

# %%
# normal band + asymmetry
#X_train = df_train[['alpha', 'beta', 'relative_gamma', 'alpha_frontal', 'alpha_temporal', 'alpha_asymmetry', 'beta_frontal', 'beta_temporal', 'beta_asymmetry', 'participant_id', 'label']]
# Asymmetry
X_train = df_train[['relative_gamma', 'alpha_frontal', 'alpha_temporal', 'alpha_asymmetry', 'beta_frontal', 'beta_temporal']]
y_train = df_train['label']

# %%
X_train.shape, y_train.shape
# Out:
# ((288, 6), (288,))

# %%
# normal band + asymmetry
#X_test = df_test[['alpha', 'beta', 'relative_gamma', 'alpha_frontal', 'alpha_temporal', 'alpha_asymmetry', 'beta_frontal', 'beta_temporal', 'beta_asymmetry', 'participant_id', 'label']]

# Asymmetry
X_test = df_test[['relative_gamma', 'alpha_frontal', 'alpha_temporal', 'alpha_asymmetry', 'beta_frontal', 'beta_temporal']]
y_test = df_test['label']

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((288, 6), (288,), (72, 6), (72,))

# %% [markdown]
# ### Feature Extraction

# %%
alpha = ['alpha_frontal', 'alpha_temporal', 'alpha_asymmetry']
gamma = ['relative_gamma']
beta = ['beta_frontal', 'beta_temporal']

alpha_beta = ['alpha_frontal', 'alpha_temporal', 'alpha_asymmetry', 'beta_frontal', 'beta_temporal']
alpha_gamma = ['relative_gamma', 'alpha_frontal', 'alpha_temporal', 'alpha_asymmetry']
beta_gamma = ['relative_gamma','beta_frontal', 'beta_temporal']

alpha_beta_gamma = ['relative_gamma', 'alpha_frontal', 'alpha_temporal', 'alpha_asymmetry', 'beta_frontal', 'beta_temporal']

type_list = [alpha,gamma,alpha_beta,alpha_gamma,beta_gamma,alpha_beta_gamma]
name_list = ['alpha','gamma','alpha_beta','alpha_gamma','beta_gamma','alpha_beta_gamma']

# %%
i = 0
for type in type_list: 
    X_train_copy, X_test_copy = X_train.copy(), X_test.copy()
    X_train_copy, X_test_copy = X_train_copy[type], X_test_copy[type]

    X_train_copy = X_train_copy.to_numpy()
    X_test_copy = X_test_copy.to_numpy()
    
    from sklearn.preprocessing import MinMaxScaler
    X_train_scaled = np.zeros_like(X_train_copy)
    X_test_scaled = np.zeros_like(X_test_copy)
    print(X_train_scaled.shape, X_test_scaled.shape)

    scalers = {}
    for i in range(X_train_copy.shape[1]):
        scalers[i] = MinMaxScaler(feature_range=(-1, 1))
        X_minmax = scalers[i].fit_transform(X_train_copy[:,i].reshape(-1, 1))
        X_train_scaled[:,i] = X_minmax[:,0]

    for i in range(X_test_copy.shape[1]):
        X_test_minmax = scalers[i].transform(X_test_copy[:,i].reshape(-1, 1))
        X_test_scaled[:,i] = X_test_minmax[:,0]

    print(name_list[i])
    train_pipe(X_train_copy, X_test_copy, y_train, y_test)
    i = i + 1
    print('-------------------------------')
# Out:
# (288, 3) (72, 3)
# alpha_beta
# SVC()
#  Train Acc : 0.6111 Score :0.5868 Test Acc : 0.4166666666666667
# LogisticRegression()
#  Train Acc : 0.5347 Score :0.5342 Test Acc : 0.4027777777777778
# GaussianNB()
#  Train Acc : 0.5590 Score :0.5589 Test Acc : 0.4305555555555556
# KNeighborsClassifier(n_neighbors=2)
#  Train Acc : 0.7500 Score :0.5380 Test Acc : 0.5416666666666666
# RandomForestClassifier()
#  Train Acc : 1.0000 Score :0.5380 Test Acc : 0.4444444444444444
# -------------------------------
# (288, 1) (72, 1)
# alpha
# SVC()
#  Train Acc : 0.6840 Score :0.6840 Test Acc : 0.9583333333333334
# LogisticRegression()
#  Train Acc : 0.6181 Score :0.6180 Test Acc : 0.8333333333333334
# GaussianNB()
#  Train Acc : 0.6875 Score :0.6909 Test Acc : 0.9305555555555556
# KNeighborsClassifier(n_neighbors=2)
#  Train Acc : 0.8264 Score :0.6600 Test Acc : 0.8611111111111112
# RandomForestClassifier()
#  Train Acc : 1.0000 Score :0.6353 Test Acc : 0.7916666666666666
# -------------------------------
# (288, 5) (72, 5)
# beta_gamma
# SVC()
#  Train Acc : 0.6424 Score :0.5837 Test Acc : 0.4027777777777778
# LogisticRegression()
#  Train Acc : 0.5625 Score :0.5450 Test Acc : 0.4027777777777778
# GaussianNB()
#  Train Acc : 0.5590 Score :0.5629 Test Acc : 0.5277777777777778
# KNeighborsClassifier(n_neighbors=2)
#  Train Acc : 0.7986 Score :0.5730 Test Acc : 0.5416666666666666
# RandomForestClassifier()
#  Train Acc : 1.0000 Score :0.6355 Test Acc : 0.5694444444444444
# -------------------------------
# (288, 4) (72, 4)
# alpha_gamma
# SVC()
#  Train Acc : 0.5833 Score :0.5834 Test Acc : 0.6666666666666666
# LogisticRegression()
#  Train Acc : 0.6146 Score :0.6217 Test Acc : 0.7916666666666666
# GaussianNB()
#  Train Acc : 0.5972 Score :0.6149 Test Acc : 0.5277777777777778
# KNeighborsClassifier(n_neighbors=2)
#  Train Acc : 0.8299 Score :0.6635 Test Acc : 0.9027777777777778
# RandomForestClassifier()
#  Train Acc : 1.0000 Score :0.6702 Test Acc : 0.8194444444444444
# -------------------------------
# (288, 3) (72, 3)
# alpha_beta
# SVC()
#  Train Acc : 0.5833 Score :0.5834 Test Acc : 0.6666666666666666
# LogisticRegression()
#  Train Acc : 0.6181 Score :0.6146 Test Acc : 0.8333333333333334
# GaussianNB()
#  Train Acc : 0.6493 Score :0.6214 Test Acc : 0.5694444444444444
# KNeighborsClassifier(n_neighbors=2)
#  Train Acc : 0.8819 Score :0.7952 Test Acc : 0.9444444444444444
# RandomForestClassifier()
#  Train Acc : 1.0000 Score :0.7880 Test Acc : 0.8888888888888888
# -------------------------------
# (288, 6) (72, 6)
# alpha_beta_gamma
# SVC()
#  Train Acc : 0.5833 Score :0.5831 Test Acc : 0.6666666666666666
# LogisticRegression()
#  Train Acc : 0.6146 Score :0.6252 Test Acc : 0.7916666666666666
# GaussianNB()
#  Train Acc : 0.5903 Score :0.6005 Test Acc : 0.5972222222222222
# KNeighborsClassifier(n_neighbors=2)
#  Train Acc : 0.8750 Score :0.7641 Test Acc : 0.9027777777777778
# RandomForestClassifier()
#  Train Acc : 1.0000 Score :0.7951 Test Acc : 0.9027777777777778
# -------------------------------

# %%
#need chunking process
