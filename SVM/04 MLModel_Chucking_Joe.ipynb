# %%
def model_SVM(X,y):
    from sklearn.svm import SVC
    from sklearn.utils import shuffle
    from sklearn.model_selection import cross_val_score

    X_shuff,y_shuff = shuffle(X,y)
    model = SVC(kernel='rbf')
    cross = cross_val_score(model, X_shuff, y_shuff, cv=5, n_jobs=-1)

    model = SVC(kernel='rbf')
    model.fit(X_shuff, y_shuff)
    ans = model.predict(X_shuff)
    acc = sum(ans == y_shuff) / len(y_shuff)
    return model, acc, cross

def model_LR(X,y):
    from sklearn.linear_model import LogisticRegression
    from sklearn.utils import shuffle
    from sklearn.model_selection import cross_val_score
    
    X_shuff,y_shuff = shuffle(X,y)
    model = LogisticRegression()
    cross = cross_val_score(model, X_shuff, y_shuff, cv=5, n_jobs=-1)

    model = LogisticRegression()
    model.fit(X_shuff, y_shuff)
    ans = model.predict(X_shuff)
    acc = sum(ans == y_shuff) / len(y_shuff)
    return model, acc, cross

def model_NB(X,y):
    from sklearn.naive_bayes import GaussianNB
    from sklearn.utils import shuffle
    from sklearn.model_selection import cross_val_score

    X_shuff,y_shuff = shuffle(X,y)
    model = GaussianNB()
    cross = cross_val_score(model, X_shuff, y_shuff, cv=5, n_jobs=-1)

    model = GaussianNB()
    model.fit(X_shuff, y_shuff)
    ans = model.predict(X_shuff)
    acc = sum(ans == y_shuff) / len(y_shuff)
    return model, acc, cross

def model_KNN(X,y):
    from sklearn.neighbors import KNeighborsClassifier
    from sklearn.utils import shuffle
    from sklearn.model_selection import cross_val_score

    X_shuff,y_shuff = shuffle(X,y)
    model = KNeighborsClassifier()
    cross = cross_val_score(model, X_shuff, y_shuff, cv=5, n_jobs=-1)

    model = KNeighborsClassifier(n_neighbors = 2)
    model.fit(X_shuff, y_shuff)
    ans = model.predict(X_shuff)
    acc = sum(ans == y_shuff) / len(y_shuff)
    return model, acc, cross

def model_RF(X,y):
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.utils import shuffle
    from sklearn.model_selection import cross_val_score

    X_shuff,y_shuff = shuffle(X,y)
    model = RandomForestClassifier()
    cross = cross_val_score(model, X_shuff, y_shuff, cv=5, n_jobs=-1)

    model = RandomForestClassifier()
    model.fit(X_shuff, y_shuff)
    ans = model.predict(X_shuff)
    acc = sum(ans == y_shuff) / len(y_shuff)
    return model, acc, cross

# %%
def test_pipe(X_test,y_test,model):
    from sklearn.metrics import accuracy_score  
    from sklearn.metrics import classification_report
    from sklearn.metrics import confusion_matrix
    import seaborn as sns
    import matplotlib.pyplot as plt
    model = model
    y_pred = model.predict(X_test)
    target_names = ['without Stress', 'with Stress']
    acc = accuracy_score(y_test,y_pred)
    # crp = classification_report(y_test,y_pred, target_names=target_names)
    print(f"Test Acc : {acc:.4f}")
    # print("classification_report : \n",crp)
    # print(sns.heatmap(confusion_matrix(y_test,y_pred),annot=True))
    # plt.show()

# %%
def train_pipe(X_train, X_test, y_train, y_test):
    X,y = X_train.copy(),y_train.copy()
    model, acc, cross = model_SVM(X,y)
    print(f'SVM Train Acc : {acc:.4f} Score :{cross.mean():.4f}',end=' ')
    test_pipe(X_test, y_test ,model)
    X,y = X_train.copy(),y_train.copy()
    model, acc, cross = model_LR(X,y) 
    print('Weight',model.coef_)
    print(f'LR  Train Acc : {acc:.4f} Score :{cross.mean():.4f}',end=' ')
    test_pipe(X_test, y_test ,model)
    X,y = X_train.copy(),y_train.copy()
    model, acc, cross = model_NB(X,y)
    print(f'NB  Train Acc : {acc:.4f} Score :{cross.mean():.4f}',end=' ')
    test_pipe(X_test, y_test ,model)
    X,y = X_train.copy(),y_train.copy()
    model, acc, cross = model_KNN(X,y)
    print(f'KNN Train Acc : {acc:.4f} Score :{cross.mean():.4f}',end=' ')
    test_pipe(X_test, y_test ,model)
    X,y = X_train.copy(),y_train.copy()
    model, acc, cross = model_RF(X,y)
    print(f'RF  Train Acc : {acc:.4f} Score :{cross.mean():.4f}',end=' ')
    test_pipe(X_test, y_test ,model)

# %%
import pandas as pd
import numpy as np

# %%
df_train = pd.read_csv('./data/joe_filter_train_set.csv')
df_train.shape
# Out:
# (900, 145)

# %%
df_train.head()
# Out:
#    Unnamed: 0  mean_Delta  mean_Theta  mean_Alpha   mean_Beta  mean_Gamma  \
# 0           0 -106.588969 -114.617508 -115.790711 -120.400378 -124.831465
# 1           1 -101.926965 -109.419453 -109.978504 -118.724397 -122.435192
# 2           2 -107.996757 -115.468109 -115.472980 -121.788114 -127.757329
# 3           3 -102.889163 -114.052748 -115.703183 -121.341409 -126.210166
# 4           4 -109.024912 -117.737440 -117.429492 -124.699051 -130.827770
#
#     mean_Slow  mean_Low_beta  mean_Relative_gamma   Fp1_Delta  ...  \
# 0 -115.085881    -118.147766             0.921930 -107.168179  ...
# 1 -109.944303    -114.976672             0.897980 -102.368628  ...
# 2 -115.739953    -118.236655             0.905936 -108.871279  ...
# 3 -114.632157    -118.040557             0.908264 -103.933410  ...
# 4 -117.596563    -122.456928             0.898865 -107.720567  ...
#
#    O2_Low_beta  O2_Relative_gamma  alpha_frontal  alpha_temporal  \
# 0  -118.741500           0.911965       0.001231        0.009129
# 1  -115.677659           0.887753      -0.003851       -0.001424
# 2  -118.022418           0.906256      -0.000033        0.002070
# 3  -118.766204           0.909694      -0.004074       -0.003062
# 4  -122.530503           0.898941      -0.002029       -0.004111
#
#    alpha_asymmetry  beta_frontal  beta_temporal  beat_asymmetry  \
# 0         0.010360     -0.000808      -0.000741       -0.001549
# 1        -0.005276     -0.001936       0.001862       -0.000074
# 2         0.002036     -0.002639      -0.003526       -0.006165
# 3        -0.007135     -0.001562       0.004495        0.002933
# 4        -0.006140     -0.001638       0.001787        0.000149
#
#    participant_id  label
# 0               1      0
# 1               1      0
# 2               1      0
# 3               1      0
# 4               1      0
#
# [5 rows x 145 columns]

# %%
np.unique(df_train['label'], return_counts=True)
# Out:
# (array([0, 1]), array([440, 460]))

# %%
# label_1 = df_train.loc[df_train['label'] == 1]
# label_1.shape

# label_0 = df_train.loc[df_train['label'] == 0].sample(n=label_1.shape[0], random_state=999)
# label_0.shape

# df_train = pd.concat([label_1, label_0])
# df_train['label'].value_counts()

label_0 = df_train.loc[df_train['label'] == 0]
label_0.shape

label_1 = df_train.loc[df_train['label'] == 1].sample(n=label_0.shape[0], random_state=999)
label_1.shape

df_train = pd.concat([label_1, label_0])
df_train['label'].value_counts()
# Out:
# 1    440
# 0    440
# Name: label, dtype: int64

# %%
df_train = df_train[['mean_Alpha', 'mean_Beta', 'mean_Relative_gamma', 'alpha_frontal', 'alpha_temporal', 'alpha_asymmetry', 'beta_frontal', 'beta_temporal', 'beat_asymmetry', 'participant_id', 'label']]
df_train.head()
# Out:
#      mean_Alpha   mean_Beta  mean_Relative_gamma  alpha_frontal  \
# 399 -117.539781 -124.071957             0.892268      -0.013011
# 106 -113.986684 -122.329545             0.908602       0.003099
# 657 -107.579439 -121.284140             0.869784       0.000039
# 817 -116.322087 -124.454611             0.889096      -0.006947
# 430 -107.377466 -121.172305             0.840705       0.004248
#
#      alpha_temporal  alpha_asymmetry  beta_frontal  beta_temporal  \
# 399        0.003552        -0.009459     -0.011348       0.006896
# 106        0.008452         0.011551     -0.001418       0.003095
# 657       -0.002678        -0.002639     -0.001142      -0.005386
# 817       -0.031607        -0.038554     -0.016290      -0.032539
# 430        0.004926         0.009174      0.000094      -0.002013
#
#      beat_asymmetry  participant_id  label
# 399       -0.004453              24      1
# 106        0.001678               8      1
# 657       -0.006528              37      1
# 817       -0.048829              49      1
# 430       -0.001918              26      1

# %%
df_train.columns = ['alpha', 'beta', 'relative_gamma', 'alpha_frontal', 'alpha_temporal', 'alpha_asymmetry', 'beta_frontal', 'beta_temporal', 'beta_asymmetry', 'participant_id', 'label']

# %%
df_train.head()
# Out:
#           alpha        beta  relative_gamma  alpha_frontal  alpha_temporal  \
# 399 -117.539781 -124.071957        0.892268      -0.013011        0.003552
# 106 -113.986684 -122.329545        0.908602       0.003099        0.008452
# 657 -107.579439 -121.284140        0.869784       0.000039       -0.002678
# 817 -116.322087 -124.454611        0.889096      -0.006947       -0.031607
# 430 -107.377466 -121.172305        0.840705       0.004248        0.004926
#
#      alpha_asymmetry  beta_frontal  beta_temporal  beta_asymmetry  \
# 399        -0.009459     -0.011348       0.006896       -0.004453
# 106         0.011551     -0.001418       0.003095        0.001678
# 657        -0.002639     -0.001142      -0.005386       -0.006528
# 817        -0.038554     -0.016290      -0.032539       -0.048829
# 430         0.009174      0.000094      -0.002013       -0.001918
#
#      participant_id  label
# 399              24      1
# 106               8      1
# 657              37      1
# 817              49      1
# 430              26      1

# %%
df_test = pd.read_csv('./data/joe_filter_test_set.csv')
df_test = df_test[['mean_Alpha', 'mean_Beta', 'mean_Relative_gamma', 'alpha_frontal', 'alpha_temporal', 'alpha_asymmetry', 'beta_frontal', 'beta_temporal', 'beat_asymmetry', 'participant_id', 'label']]
df_test.columns = ['alpha', 'beta', 'relative_gamma', 'alpha_frontal', 'alpha_temporal', 'alpha_asymmetry', 'beta_frontal', 'beta_temporal', 'beta_asymmetry', 'participant_id', 'label']

# %% [markdown]
# #### Select only Asymmetry

# %%
# normal band + asymmetry
#X_train = df_train[['alpha', 'beta', 'relative_gamma', 'alpha_frontal', 'alpha_temporal', 'alpha_asymmetry', 'beta_frontal', 'beta_temporal', 'beta_asymmetry', 'participant_id', 'label']]
# Asymmetry
X_train = df_train[['relative_gamma', 'alpha_frontal', 'alpha_temporal', 'alpha_asymmetry', 'beta_frontal', 'beta_temporal']]
y_train = df_train['label']

# %%
X_train.shape, y_train.shape
# Out:
# ((880, 6), (880,))

# %%
# normal band + asymmetry
#X_test = df_test[['alpha', 'beta', 'relative_gamma', 'alpha_frontal', 'alpha_temporal', 'alpha_asymmetry', 'beta_frontal', 'beta_temporal', 'beta_asymmetry', 'participant_id', 'label']]

# Asymmetry
X_test = df_test[['relative_gamma', 'alpha_frontal', 'alpha_temporal', 'alpha_asymmetry', 'beta_frontal', 'beta_temporal']]
y_test = df_test['label']

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((880, 6), (880,), (200, 6), (200,))

# %% [markdown]
# ### Feature Extraction

# %%
alpha = ['alpha_frontal', 'alpha_temporal', 'alpha_asymmetry']
gamma = ['relative_gamma']
beta = ['beta_frontal', 'beta_temporal']

alpha_beta = ['alpha_frontal', 'alpha_temporal', 'alpha_asymmetry', 'beta_frontal', 'beta_temporal']
alpha_gamma = ['relative_gamma', 'alpha_frontal', 'alpha_temporal', 'alpha_asymmetry']
beta_gamma = ['relative_gamma','beta_frontal', 'beta_temporal']

alpha_beta_gamma = ['relative_gamma', 'alpha_frontal', 'alpha_temporal', 'alpha_asymmetry', 'beta_frontal', 'beta_temporal']

type_list = [alpha,beta,gamma,alpha_beta,alpha_gamma,beta_gamma,alpha_beta_gamma]
name_list = ['alpha','beta','gamma','alpha_beta','alpha_gamma','beta_gamma','alpha_beta_gamma']

# %%
for j, type in enumerate(type_list): 
    print(name_list[j])
    X_train_copy, X_test_copy = X_train.copy(), X_test.copy()
    X_train_copy, X_test_copy = X_train_copy[type], X_test_copy[type]

    X_train_copy = X_train_copy.to_numpy()
    X_test_copy = X_test_copy.to_numpy()
    
    from sklearn.preprocessing import MinMaxScaler
    X_train_scaled = np.zeros_like(X_train_copy)
    X_test_scaled = np.zeros_like(X_test_copy)
    # print(X_train_scaled.shape, X_test_scaled.shape)

    scalers = {}
    for i in range(X_train_copy.shape[1]):
        scalers[i] = MinMaxScaler(feature_range=(-1, 1))
        X_minmax = scalers[i].fit_transform(X_train_copy[:,i].reshape(-1, 1))
        X_train_scaled[:,i] = X_minmax[:,0]

    for i in range(X_test_copy.shape[1]):
        X_test_minmax = scalers[i].transform(X_test_copy[:,i].reshape(-1, 1))
        X_test_scaled[:,i] = X_test_minmax[:,0]
    train_pipe(X_train_scaled, X_test_scaled, y_train, y_test)
# Out:
# alpha
# SVM Train Acc : 0.5989 Score :0.5602 Test Acc : 0.5500
# Weight [[-0.64180732  0.18983068 -0.3134663 ]]
# LR  Train Acc : 0.5159 Score :0.5045 Test Acc : 0.4250
# NB  Train Acc : 0.5148 Score :0.5125 Test Acc : 0.5000
# KNN Train Acc : 0.7784 Score :0.5295 Test Acc : 0.5400
# RF  Train Acc : 1.0000 Score :0.5739 Test Acc : 0.5400
# beta
# SVM Train Acc : 0.6830 Score :0.6727 Test Acc : 0.4450
# Weight [[-1.43936097  0.87615003]]
# LR  Train Acc : 0.5705 Score :0.5659 Test Acc : 0.3950
# NB  Train Acc : 0.6148 Score :0.6159 Test Acc : 0.5100
# KNN Train Acc : 0.8136 Score :0.6432 Test Acc : 0.5300
# RF  Train Acc : 1.0000 Score :0.6477 Test Acc : 0.5150
# gamma
# SVM Train Acc : 0.5795 Score :0.5659 Test Acc : 0.4750
# Weight [[-0.10273343]]
# LR  Train Acc : 0.5102 Score :0.5091 Test Acc : 0.4700
# NB  Train Acc : 0.5057 Score :0.4943 Test Acc : 0.4100
# KNN Train Acc : 0.7648 Score :0.5023 Test Acc : 0.4600
# RF  Train Acc : 1.0000 Score :0.5045 Test Acc : 0.4950
# alpha_beta
# SVM Train Acc : 0.7091 Score :0.6966 Test Acc : 0.4750
# Weight [[ 0.11734987 -0.27545477 -0.12931211 -1.43361606  1.01299004]]
# LR  Train Acc : 0.5659 Score :0.5636 Test Acc : 0.3650
# NB  Train Acc : 0.6420 Score :0.6148 Test Acc : 0.5150
# KNN Train Acc : 0.8227 Score :0.6898 Test Acc : 0.5100
# RF  Train Acc : 1.0000 Score :0.6955 Test Acc : 0.4700
# alpha_gamma
# SVM Train Acc : 0.6443 Score :0.6057 Test Acc : 0.4700
# Weight [[-0.10980597 -0.64487442  0.19086237 -0.31500609]]
# LR  Train Acc : 0.5068 Score :0.4955 Test Acc : 0.4400
# NB  Train Acc : 0.5489 Score :0.5239 Test Acc : 0.4600
# KNN Train Acc : 0.7875 Score :0.6170 Test Acc : 0.4900
# RF  Train Acc : 1.0000 Score :0.6057 Test Acc : 0.5050
# beta_gamma
# SVM Train Acc : 0.7159 Score :0.6943 Test Acc : 0.4450
# Weight [[-0.17268803 -1.44912337  0.90687343]]
# LR  Train Acc : 0.5795 Score :0.5648 Test Acc : 0.4250
# NB  Train Acc : 0.6102 Score :0.6068 Test Acc : 0.5200
# KNN Train Acc : 0.8375 Score :0.7500 Test Acc : 0.5400
# RF  Train Acc : 1.0000 Score :0.7239 Test Acc : 0.4600
# alpha_beta_gamma
# SVM Train Acc : 0.7364 Score :0.7159 Test Acc : 0.5200
# Weight [[-0.18094982  0.11792233 -0.28842521 -0.13342467 -1.44293211  1.05193641]]
# LR  Train Acc : 0.5705 Score :0.5580 Test Acc : 0.4100
# NB  Train Acc : 0.6409 Score :0.6341 Test Acc : 0.4800
# KNN Train Acc : 0.8693 Score :0.7455 Test Acc : 0.5000
# RF  Train Acc : 1.0000 Score :0.7330 Test Acc : 0.4400

# %%
#need chunking process
